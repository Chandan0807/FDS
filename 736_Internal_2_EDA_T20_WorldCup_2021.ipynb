# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("t20_WorldCup_2021.csv")

# %%
df
# Out:
#    Match_No.       team_1       team_2        stage  Winner_toss  \
# 0    Match_1    Australia  SouthAfrica  Group_stage    Australia
# 1    Match_2      England      Windies  Group_stage      England
# 2    Match_3     Srilanka   Bangladesh  Group_stage     Srilanka
# 3    Match_4     Pakistan        India  Group_stage     Pakistan
# 4    Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
# 5    Match_6  SouthAfrica      Windies  Group_stage  SouthAfrica
# 6    Match_7     Pakistan  New_Zealand  Group_stage     Pakistan
# 7    Match_8      England   Bangladesh  Group_stage   Bangladesh
# 8    Match_9      Namibia     ScotLand  Group_stage      Namibia
# 9   Match_10    Australia     Srilanka  Group_stage    Australia
# 10  Match_11      Windies   Bangladesh  Group_stage   Bangladesh
# 11  Match_12     Pakistan  Afghanistan  Group_stage  Afghanistan
# 12  Match_13  SouthAfrica     Srilanka  Group_stage  SouthAfrica
# ...

# %%
df.head()
# Out:
#   Match_No.       team_1       team_2        stage  Winner_toss  \
# 0   Match_1    Australia  SouthAfrica  Group_stage    Australia
# 1   Match_2      England      Windies  Group_stage      England
# 2   Match_3     Srilanka   Bangladesh  Group_stage     Srilanka
# 3   Match_4     Pakistan        India  Group_stage     Pakistan
# 4   Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
#
#   Toss_descision       time      venue  avg_temperature       best_bowler  \
# 0       Fielding  afternoon  Abu_Dhabi               30    Josh_Hazlewood
# 1       Fielding    evening      Dubai               33       Adil_Rashid
# 2       Fielding  afternoon    Sharjah               34  Shakib_al_Hassan
# 3       Fielding    evening      Dubai               34      Shaheen_shah
# 4        Batting    evening    Sharjah               33  Mujeeb_ur_Rehman
#
#    ... best_bowler_country        best_batter  batting_hand  \
# 0  ...           Australia      Aiden_Markram         Right
# ...

# %%
df.tail()
# Out:
#    Match_No.       team_1       team_2        stage  Winner_toss  \
# 28  Match_29     Pakistan     ScotLand  Group_stage     Pakistan
# 29  Match_30        India      Namibia  Group_stage        India
# 30  Match_31  New_Zealand      England   Semi_Final  New_Zealand
# 31  Match_32    Australia     Pakistan   Semi_Final    Australia
# 32  Match_33    Australia  New_Zealand        Final    Australia
#
#    Toss_descision     time      venue  avg_temperature       best_bowler  ...  \
# 28        Batting  evening    Sharjah               27       Shadab_Khan  ...
# 29       Fielding  evening      Dubai               28   Ravindra_Jadeja  ...
# 30       Fielding  evening  Abu_Dhabi               28  Liam_Livingstone  ...
# 31       Fielding  evening      Dubai               29       Shadab_Khan  ...
# 32       Fielding  evening      Dubai               26    Josh_Hazlewood  ...
#
#    best_bowler_country      best_batter  batting_hand  high_indvidual_scores  \
# ...

# %%
df.columns
# Out:
# Index(['Match_No.', 'team_1', 'team_2', 'stage', 'Winner_toss',
#        'Toss_descision', 'time', 'venue', 'avg_temperature', 'best_bowler',
#        'bowling_arm', 'bowling_style', 'most_individual_wickets', 'economy',
#        'best_bowler_country', 'best_batter', 'batting_hand',
#        'high_indvidual_scores', 'strike_rate', 'best_batter_team', 'target',
#        'target_achieved', 'Player_of_the_match', 'Winner'],
#       dtype='object')

# %%
df.shape
# Out:
# (33, 24)

# %%
df.mean()
# Out:
# avg_temperature             29.272727
# most_individual_wickets      2.878788
# economy                      5.215758
# high_indvidual_scores       62.393939
# strike_rate                152.402121
# target                     146.606061
# target_achieved              0.696970
# dtype: float64

# %%
df.dtypes
# Out:
# Match_No.                   object
# team_1                      object
# team_2                      object
# stage                       object
# Winner_toss                 object
# Toss_descision              object
# time                        object
# venue                       object
# avg_temperature              int64
# best_bowler                 object
# bowling_arm                 object
# bowling_style               object
# most_individual_wickets      int64
# economy                    float64
# best_bowler_country         object
# best_batter                 object
# batting_hand                object
# high_indvidual_scores        int64
# strike_rate                float64
# best_batter_team            object
# target                       int64
# target_achieved              int64
# Player_of_the_match         object
# Winner                      object
# dtype: object

# %%
df.Winner = pd.Categorical(df.Winner)

# %%
df.isnull().sum()
# Out:
# Match_No.                  0
# team_1                     0
# team_2                     0
# stage                      0
# Winner_toss                0
# Toss_descision             0
# time                       0
# venue                      0
# avg_temperature            0
# best_bowler                0
# bowling_arm                0
# bowling_style              0
# most_individual_wickets    0
# economy                    0
# best_bowler_country        0
# best_batter                0
# batting_hand               0
# high_indvidual_scores      0
# strike_rate                0
# best_batter_team           0
# target                     0
# target_achieved            0
# Player_of_the_match        0
# Winner                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Match_No.                33 non-null     object
#  1   team_1                   33 non-null     object
#  2   team_2                   33 non-null     object
#  3   stage                    33 non-null     object
#  4   Winner_toss              33 non-null     object
#  5   Toss_descision           33 non-null     object
#  6   time                     33 non-null     object
#  7   venue                    33 non-null     object
#  8   avg_temperature          33 non-null     int64
#  9   best_bowler              33 non-null     object
#  10  bowling_arm              33 non-null     object
#  11  bowling_style            33 non-null     object
#  12  most_individual_wickets  33 non-null     int64
#  13  economy                  33 non-null     float64
# ...

# %%
print("Mean : {0}\nCount : {1}\nMin : {2}\nMax : {3}\nSum : {4}\nStandart Deviation : {5}\nVariance : {6}".format(
df["target"].mean(),
df["target"].count(),
df["target"].min(),
df["target"].max(),
df["target"].sum(),
df["target"].std(),
df["target"].var()))
# Out:
# Mean : 146.6060606060606
# Count : 33
# Min : 56
# Max : 211
# Sum : 4838
# Standart Deviation : 37.13652127113163
# Variance : 1379.121212121212

# %%
df.describe().T
# Out:
#                          count        mean        std    min     25%     50%  \
# avg_temperature           33.0   29.272727   2.577217  20.00   28.00   29.00
# most_individual_wickets   33.0    2.878788   0.892944   1.00    2.00    3.00
# economy                   33.0    5.215758   2.187966   0.90    4.00    4.80
# high_indvidual_scores     33.0   62.393939  20.135385  24.00   45.00   65.00
# strike_rate               33.0  152.402121  33.999070  97.06  136.36  153.19
# target                    33.0  146.606061  37.136521  56.00  125.00  152.00
# target_achieved           33.0    0.696970   0.466694   0.00    0.00    1.00
#
#                             75%     max
# avg_temperature           30.00   34.00
# most_individual_wickets    3.00    5.00
# economy                    6.25   12.00
# high_indvidual_scores     79.00  101.00
# strike_rate              162.90  263.16
# target                   173.00  211.00
# target_achieved            1.00    1.00

# %%
df.groupby("Winner").mean().head(10).T
# Out:
# Winner                   Afghanistan   Australia   England       India  \
# avg_temperature               31.500   27.000000   30.2500   28.333333
# most_individual_wickets        4.000    3.333333    3.2500    3.000000
# economy                        3.625    5.466667    4.2875    5.250000
# high_indvidual_scores         52.000   64.333333   64.2500   60.000000
# strike_rate                  154.945  155.120000  160.5375  190.653333
# target                       176.000  142.666667  117.7500  143.333333
# target_achieved                0.000    1.000000    0.7500    0.666667
#
# Winner                   Namibia  New_Zealand  Pakistan  SouthAfrica  \
# avg_temperature            29.00        28.80    29.800      30.2500
# most_individual_wickets     3.00         2.40     2.400       3.0000
# economy                     4.25         5.10     5.460       6.6750
# high_indvidual_scores      44.00        65.20    61.600      63.2500
# ...

# %%
df.groupby("stage")["target"].mean().head()
# Out:
# stage
# Final          173.000000
# Group_stage    144.033333
# Semi_Final     172.000000
# Name: target, dtype: float64

# %%
df.stage.unique()
# Out:
# array(['Group_stage', 'Semi_Final', 'Final'], dtype=object)

# %%
df["Winner"].value_counts().count()
# Out:
# 10

# %%
df["stage"].value_counts().head(15)
# Out:
# Group_stage    30
# Semi_Final      2
# Final           1
# Name: stage, dtype: int64

# %%
df["Winner"].value_counts().plot.barh().set_title("\"Winner\"Winners Of Macthes");

# %%
df.head()
# Out:
#   Match_No.       team_1       team_2        stage  Winner_toss  \
# 0   Match_1    Australia  SouthAfrica  Group_stage    Australia
# 1   Match_2      England      Windies  Group_stage      England
# 2   Match_3     Srilanka   Bangladesh  Group_stage     Srilanka
# 3   Match_4     Pakistan        India  Group_stage     Pakistan
# 4   Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
#
#   Toss_descision       time      venue  avg_temperature       best_bowler  \
# 0       Fielding  afternoon  Abu_Dhabi               30    Josh_Hazlewood
# 1       Fielding    evening      Dubai               33       Adil_Rashid
# 2       Fielding  afternoon    Sharjah               34  Shakib_al_Hassan
# 3       Fielding    evening      Dubai               34      Shaheen_shah
# 4        Batting    evening    Sharjah               33  Mujeeb_ur_Rehman
#
#    ... best_bowler_country        best_batter  batting_hand  \
# 0  ...           Australia      Aiden_Markram         Right
# ...

# %%
df["team_1"].value_counts().plot.barh().set_title("\"team_1")
# Out:
# Text(0.5, 1.0, '"team_1')

# %%
df["team_2"].value_counts().plot.barh().set_title("\"team_2")
# Out:
# Text(0.5, 1.0, '"team_2')

# %%
sns.barplot(x = "target_achieved", y = df.target, data = df);

# %%
sns.catplot(x = "stage", y = "Player_of_the_match", data = df);

# %%
sns.barplot(x = "high_indvidual_scores", y = "target", hue = "stage", data = df.head(30))
# Out:
# <AxesSubplot:xlabel='high_indvidual_scores', ylabel='target'>

# %%
sns.boxplot(x = df.high_indvidual_scores);
